# %% [markdown]
# <a href="https://colab.research.google.com/github/PrasadJagdale1939/Google_Colab_Practice/blob/main/API_INTEGRATION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai

# %%
from google.colab import userdata
userdata.get("My_API") #verifies API Key
# Out:
# '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'

# %%
from openai import OpenAI
from google.colab import userdata
client = OpenAI(api_key=userdata.get("My_API"),base_url="https://integrate.api.nvidia.com/v1")
for model in client.models.list().data:
  print(f"Model : {model.id}, Owned by : {model.owned_by}")
# Out:
# Model : 01-ai/yi-large, Owned by : 01-ai
# Model : adept/fuyu-8b, Owned by : adept
# Model : ai21labs/jamba-1.5-large-instruct, Owned by : ai21labs
# Model : aisingapore/sea-lion-7b-instruct, Owned by : aisingapore
# Model : bigcode/starcoder2-15b, Owned by : bigcode
# Model : databricks/dbrx-instruct, Owned by : databricks
# Model : deepseek-ai/deepseek-coder-6.7b-instruct, Owned by : deepseek-ai
# Model : deepseek-ai/deepseek-v4-flash-0731, Owned by : deepseek-ai
# Model : deepseek-ai/deepseek-v4-pro-0813, Owned by : deepseek-ai
# Model : google/codegemma-1.1-7b, Owned by : google
# Model : google/codegemma-7b, Owned by : google
# Model : google/deplot, Owned by : google
# Model : google/diffusiongemma-26b-a4b-it, Owned by : google
# Model : google/gemma-2b, Owned by : google
# Model : google/gemma-3-12b-it, Owned by : google
# Model : google/gemma-3-4b-it, Owned by : google
# Model : google/gemma-4-31b-it, Owned by : google
# Model : google/recurrentgemma-2b, Owned by : google
# ...

# %%
from openai import OpenAI
from google.colab import userdata
client = OpenAI(api_key=userdata.get("My_API"),base_url="https://integrate.api.nvidia.com/v1")

question= input("Enter Your Question ?")
response= client.chat.completions.create(
    model="deepseek-ai/deepseek-v4-flash-0731",
    messages=[{"role":"user","content":question}]
)


#print(response)
print(response.choices[0].message.content)
# Out:
# Enter Your Question ?What is Database ?
# At its simplest, a **database** is an organized collection of data, stored and accessed electronically.
#
# Think of it as a highly advanced, digital filing cabinet. Just as a filing cabinet uses folders and tabs to keep paperwork organized so you can find a specific document quickly, a database structures information so a computer (or a user) can find, update, and manage it efficiently.
#
# Here’s a breakdown to make it even clearer:
#
# ### 1. The Database vs. The DBMS (The most common confusion)
# - **The Database:** This is just the *data* itself. It is the raw facts and information, like a list of customer names, addresses, and purchase histories.
# ...
